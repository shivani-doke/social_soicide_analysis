# %%
import numpy as np
import pandas as pd
import seaborn as sns

df = pd.read_csv(r'E:\41TS\smmh.csv')
df.head()
# Out:
#             Timestamp  1. What is your age? 2. Gender 3. Relationship Status  \
# 0  4/18/2022 19:18:47                  21.0      Male      In a relationship
# 1  4/18/2022 19:19:28                  21.0    Female                 Single
# 2  4/18/2022 19:25:59                  21.0    Female                 Single
# 3  4/18/2022 19:29:43                  21.0    Female                 Single
# 4  4/18/2022 19:33:31                  21.0    Female                 Single
#
#   4. Occupation Status 5. What type of organizations are you affiliated with?  \
# 0   University Student                                         University
# 1   University Student                                         University
# 2   University Student                                         University
# 3   University Student                                         University
# 4   University Student                                         University
#
#   6. Do you use social media?  \
# ...

# %%
# Split the social media platforms into separate rows
social_media_series = df['7. What social media platforms do you commonly use?'].str.split(', ').explode()

# Count the occurrences of each platform
social_media_counts = social_media_series.value_counts()

# Plot the data
plt.figure(figsize=(12, 6))
social_media_counts.plot(kind='bar', color='skyblue')
plt.title('Most Used Social Media Platforms')
plt.xlabel('Social Media Platform')
plt.ylabel('Number of Users')
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting the data
plt.figure(figsize=(12, 6))

# Count the occurrences of each response for depression and sleep issues
depression_counts = df['18. How often do you feel depressed or down?'].value_counts().sort_index()
sleep_issues_counts = df['20. On a scale of 1 to 5, how often do you face issues regarding sleep?'].value_counts().sort_index()

# Plotting the depression data
plt.subplot(1, 2, 1)
depression_counts.plot(kind='bar', color='skyblue')
plt.title('Frequency of Feeling Depressed or Down')
plt.xlabel('Scale (1-5)')
plt.ylabel('Number of People')

# Plotting the sleep issues data
plt.subplot(1, 2, 2)
sleep_issues_counts.plot(kind='bar', color='salmon')
plt.title('Frequency of Facing Sleep Issues')
plt.xlabel('Scale (1-5)')
plt.ylabel('Number of People')

plt.tight_layout()
plt.show()

# %%
# Filter the dataframe for single participants
single_df = df[df['3. Relationship Status'] == 'Single']

# Split the social media platforms into separate rows for single participants
single_social_media_series = single_df['7. What social media platforms do you commonly use?'].str.split(', ').explode()

# Count the occurrences of each platform for single participants
single_social_media_counts = single_social_media_series.value_counts()

# Plot the data
plt.figure(figsize=(12, 6))
single_social_media_counts.plot(kind='bar', color='skyblue')
plt.title('Most Used Social Media Platforms by Single Participants')
plt.xlabel('Social Media Platform')
plt.ylabel('Number of Users')
plt.xticks(rotation=45)
plt.show()
